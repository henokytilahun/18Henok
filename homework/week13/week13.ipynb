# %% [markdown]
# ### Homework 13 Problem 1:
#
# Use the dataset available at the following link to predict the cooling load of buildings based on their architectural features e.g. height, wall area, roof area, etc. You can choose any regression algorithm you like available in the `scikit-learn` package other than `LinearRegressor`. Systematically tune your model. You should optimize both (1) your input variables and (2) model parameters to come up with the best model possible. Walk through your logic for both tuning steps.
#
#
# https://archive.ics.uci.edu/dataset/242/energy+efficiency

# %% [markdown]
# ### Homework 13 Problem 2:
#
# Use the following data from a chemical analysis of different wines to classify the region in which they were grown. Use a classification algorithm to predict the wine region after splitting the data into training and test datasets. You are responsible for tuning the model to be as accurate as possible. Try comparing the following as a part of your analysis:
# 1. Compare the accuracy of at least two different models.
# 2. Select the best combination of input variables, remembering that more is not always better
# 3. Tune the model parameters to find the best balance of bias versus variance.
#
# Interpret your results, and justify your decisions for your final model.
#
#
# https://archive.ics.uci.edu/dataset/109/wine

# %% [markdown]
# ### Problem 3 Reflection
#
# On every homework assignment. This should be at least 5 sentences and demonstrate engagement with the material that goes beyond "this was hard" or "this was cool." Things you may include are:
#
# - What was most challenging and why
# - How you approached a problem
# - What you learned outside of class on your own
# - How material complements what you are learning in other classes
# - Feel free to take it any direction you want, but it needs to meet the above criteria to get full credit

# %% [markdown]
# # AI Acknowledgement Statement
#
# Please indicate if and how you used ChatGPT or other LLMs on this assignment. Use the option that best fits your use case:
#
# * [ ] I did not use ChatGPT/LLMs.
# * [X] I consulted ChatGPT/LLMs (to brainstorm, to debug, to get information, to give feedback), but I did not copy and paste or use text directly from ChatGPT/LLMs.
# * [ ] I copied and pasted portions of code directly from ChatGPT/LLMs.
# * [ ] I consulted other outside sources other than ChatGPT/LLMs.
