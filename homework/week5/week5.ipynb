# %% [markdown]
# ### Homework 5 Problem 1:
# You want to know how far off your interpolation estimations might be. You are going to explore this question using a normal distribution, a common function that is looked up using tables.
#
# 1. Create your own normal distribution table using the scipy.norm.pdf function for values between -5 and +5 in 0.1 intervals.
# 2. You assume that the worst errors in your interpolation will occur at the midpoint between each pair of datapoints. With this assumption, calculate interpolations of the normal distribution at -4.95, -4.85, -4.75, etc for each pair of points in your dataset.
# 3. Calculate the true value of the normal distribution at all the points found in (2). Calculate their errors, find the maximum error and where it occurs. What observations can you make?
# 4. Repeat 1.-3. for a normal distribution table with 0.01 intervals. How does the value of the maximum error change?
# 5. Repeat 2.-3. using a non-linear interpolation scheme of your choice. How does the value of the maximum error change?

# %% [markdown]
# ### Homework 5 Problem 2:
#
# You have access to the following dataset on blood pressure of boys broken down by age and height percentiles. Create a widget that allows the user to specify:
# 1. age
# 2. height (as a percentile)
# 3. blood pressure (as a percentile)
#
# and returns the blood pressure in mm Hg. For example, if I know a 5-year old boy is in the 92th percentile for height and is in the 76th percentile for blood pressure, I should be able to look up his blood pressure. This will require use of reading in data files, widgets, and interpolation functions.

# %% [markdown]
# ### Problem 3 Reflection
#
# On every homework assignment. This should be at least 5 sentences and demonstrate engagement with the material that goes beyond "this was hard" or "this was cool." Things you may include are:
#
# - What was most challenging and why
# - How you approached a problem
# - What you learned outside of class on your own
# - How material complements what you are learning in other classes
# - Feel free to take it any direction you want, but it needs to meet the above criteria to get full credit

# %% [markdown]
# # AI Acknowledgement Statement
#
# Please indicate if and how you used ChatGPT or other LLMs on this assignment. Use the option that best fits your use case:
#
# * [ ] I did not use ChatGPT/LLMs.
# * [X] I consulted ChatGPT/LLMs (to brainstorm, to debug, to get information, to give feedback), but I did not copy and paste or use text directly from ChatGPT/LLMs.
# * [ ] I copied and pasted portions of code directly from ChatGPT/LLMs.
# * [ ] I consulted other outside sources other than ChatGPT/LLMs.
