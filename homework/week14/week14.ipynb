# %% [markdown]
# ### Homework 14 Problem 1:
#
# We found out from today's lecture that you often need to prepare your input dataset quite a bit in order to get satisfactory predictions. A few problems you might have encountered:
# - What if I have a non-numerical feature?
# - What if one of my features has missing values?
# - Can I have too many or too few features?
#
# Build on your model from class today using one of the following feature engineering or data cleaning tools from the sklearn package:
# - Labelling functions e.g. `OneHotEncoder` or `LabelEncoder` that turn categorical data into numerical data in different ways
# - The `SimpleImputer` function that fills in missing data by looking at similar values in your input dataset.
# - The `pca` function or Principle Component Analysis function that can take a large number of inputs and reduce it to a smaller number of inputs that contains the same information.
#
# Other things you may consider to get a more accurate model:
# - Extracting titles (e.g., Mr., Mrs., Miss) from the Name field helps capture social status, age, and gender information.
# - Combining `SibSp` and `Parch` to create a `FamilySize` feature (i.e., `SibSp` + `Parch` + 1) provides insight into family groupings. An `IsAlone` feature indicates if a passenger was traveling alone, which can be a significant factor in survival chances.
# - Binning continuous variables like `Fare` and `Age` into categories helps models capture non-linear relationships. For example, categorizing `Fare` into low, medium, and high brackets can highlight survival patterns across different fare levels.
# - Although the `Cabin` and `Ticket` fields are messy, extracting information such as the first letter of the cabin (which indicates the deck level) or the prefix of the ticket can provide additional context. These features can correlate with passenger class or location on the ship.
# - The port of embarkation (`Embarked`) can be a proxy for socio-economic status or regional demographics.

# %% [markdown]
# ### Homework 14 Problem 2:
#
# As mentioned in class, machine learning specialists spend a lot of their time optimizing their model hyperparameters. In this problem, you are going to find the best set of parameters for your digit-reading neural network from class. Please select 4 different hyperparameters you would like to adjust, and pick a range of values (at least 3 per parameter) for a total of at least 4x3=12 different models. Select the best set of parameters based on your grid search.
#
# To complete your hyperparameter search, you can either manually perform it using for loops or you can try out `sklearn`'s function for this `GridSearchCV`.
#
# GridSearchCV — scikit-learn 1.6.1 documentation

# %% [markdown]
# ### Problem 3 Reflection
#
# On every homework assignment. This should be at least 5 sentences and demonstrate engagement with the material that goes beyond "this was hard" or "this was cool." Things you may include are:
#
# - What was most challenging and why
# - How you approached a problem
# - What you learned outside of class on your own
# - How material complements what you are learning in other classes
# - Feel free to take it any direction you want, but it needs to meet the above criteria to get full credit

# %% [markdown]
# # AI Acknowledgement Statement
#
# Please indicate if and how you used ChatGPT or other LLMs on this assignment. Use the option that best fits your use case:
#
# * [ ] I did not use ChatGPT/LLMs.
# * [X] I consulted ChatGPT/LLMs (to brainstorm, to debug, to get information, to give feedback), but I did not copy and paste or use text directly from ChatGPT/LLMs.
# * [ ] I copied and pasted portions of code directly from ChatGPT/LLMs.
# * [ ] I consulted other outside sources other than ChatGPT/LLMs.
