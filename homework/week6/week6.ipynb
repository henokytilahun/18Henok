# %% [markdown]
# ### Homework 6 Problem 1:
#
# 1. Read in a sound .wav file using the read function, and isolate a small portion of it (say, 5 seconds) for analysis. Plot the sound data in both the time domain and in the frequency domain (after performing the Fourier transform on it). Comment on any important observations you make. Is this a chord? Are there low, middle, and high frequencies?
# 2. Select a set of related sounds that you can compare in both the time and frequency domains e.g. notes on the piano, different instruments playing the same note, different voices saying the same vowel sound, etc. Repeat (1) for your set of sound files. Include at least 4 different sounds in your analysis

# %% [markdown]
# ### Homework 6 Problem 2:
#
# Samantha is running a lemonade stand and sells three products:
# - Basic lemonade (B)
# - Flavored lemonade (F)
# - Large lemonade (L)
#
# After a day of business, she counts the following:
# - She sold a total of 50 drinks
# - The revenue of all drinks was $140.
# - Basic lemonade costs $2
# - Flavored lemonade costs $3
# - Large lemonade costs $4
#
# She noticed that the number of Basic Lemonades was equal to the sum of the Flavored and Large Lemonades.
# 1. Write a system of 3 equations and 3 unknowns (B, F, and L) that describes the given scenario.
# 2. Use Python to (1) Find the inverse of the corresponding matrix and (2) the number of each type of lemonade B, F, and L.

# %% [markdown]
# ### Problem 3 Reflection
#
# On every homework assignment. This should be at least 5 sentences and demonstrate engagement with the material that goes beyond "this was hard" or "this was cool." Things you may include are:
#
# - What was most challenging and why
# - How you approached a problem
# - What you learned outside of class on your own
# - How material complements what you are learning in other classes
# - Feel free to take it any direction you want, but it needs to meet the above criteria to get full credit

# %% [markdown]
# # AI Acknowledgement Statement
#
# Please indicate if and how you used ChatGPT or other LLMs on this assignment. Use the option that best fits your use case:
#
# * [ ] I did not use ChatGPT/LLMs.
# * [X] I consulted ChatGPT/LLMs (to brainstorm, to debug, to get information, to give feedback), but I did not copy and paste or use text directly from ChatGPT/LLMs.
# * [ ] I copied and pasted portions of code directly from ChatGPT/LLMs.
# * [ ] I consulted other outside sources other than ChatGPT/LLMs.
