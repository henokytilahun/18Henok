# %% [markdown]
# ### Homework 7 Problem 1:
#
# I have provided below solar radiation data for Lake Mead in 2023 from the National Solar Radiation Database. The data is provided in 15-minute intervals, and the solar radiation is reported in terms of the Global Horizontal Irradiance (GHI), which is basically the amount of solar power per square foot available from the sun at a given location (units are in watts per meters squared).
#
# Create a widget that allows the user to select a given day (in terms of the day and month), plots the data from the given day, and calculates the total energy from the sun per meter squared e.g. calculate the integral. Report total energy in kilojoules (kJ). Add the total energy available as text in your plot.
#
# **Note**: Unlike in class, you will be unable to adjust the delta when calculating the integral. The data was collected in 15-minute intervals, so the base of your rectangle (or trapezoid or other shape will be fixed at 15 minutes). Note as well that 1 watt = 1 Joule/second  and 1 kilowatt = 1 kilojoule/second. You will need to take this into account when calculating the integral, which is in units of energy e.g. kJ. If your x axis is in units of minutes, you will need to convert minutes to seconds.

# %% [markdown]
# ### Homework 7 Problem 2:
#
# You would like to explore the dynamics of a massless spring e.g. how the position of a spring changes over time when the initial position and velocity are modified. You are going to use odeint from the scipy.integrate library to solve the second order differential equation shown below -- note that I have also given you the system of two first-order differential equations, which is the expected input for the odeint function. Do the following:
#
# 1. Make a phase diagram of position and velocity (e.g. y1 and y2) using the quiver function. Note that the direction of each arrow is determined by the change in position (y1 prime) and the change in velocity (y2 prime)
# 2. Create a static plot of the trajectory of the spring when the spring constant k is 0.1, the initial velocity is 0, and the initial position is 3. Plot the solution over the time interval 0 to 10.
# 3. Create a widget that allows the user to change the spring constant, the initial position, and the initial velocity to explore how the solution changes under different conditions. Vary k from 0.1 to 10, vary the initial position from -10 to 10, and vary the initial velocity from -10 to 10.
#
# *Note that this problem is very similar to the ODE we did in class, you just need to tweak the code we did together slightly.
# Note also that you will want to use the `args` method in odeint when you get to the part where you want to vary the spring constant k. k should be an input to your ode function, so you can change it, but `odeint` needs to know its value when you go to integrate.*

# %% [markdown]
# ### Problem 3 Reflection
#
# On every homework assignment. This should be at least 5 sentences and demonstrate engagement with the material that goes beyond "this was hard" or "this was cool." Things you may include are:
#
# - What was most challenging and why
# - How you approached a problem
# - What you learned outside of class on your own
# - How material complements what you are learning in other classes
# - Feel free to take it any direction you want, but it needs to meet the above criteria to get full credit

# %% [markdown]
# # AI Acknowledgement Statement
#
# Please indicate if and how you used ChatGPT or other LLMs on this assignment. Use the option that best fits your use case:
#
# * [ ] I did not use ChatGPT/LLMs.
# * [X] I consulted ChatGPT/LLMs (to brainstorm, to debug, to get information, to give feedback), but I did not copy and paste or use text directly from ChatGPT/LLMs.
# * [ ] I copied and pasted portions of code directly from ChatGPT/LLMs.
# * [ ] I consulted other outside sources other than ChatGPT/LLMs.
