# %%
import cv2
import numpy as np

# %%
# Create a blank white image (500x500 pixels)
img = np.full((500, 500, 3), 255, dtype=np.uint8)
coins = [
    {"center": (100, 100), "radius": 20, "color": (192, 192, 192)},
    {"center": (300, 100), "radius": 25, "color": (50, 100, 200)},
    {"center": (100, 300), "radius": 30, "color": (180, 180, 180)},
    {"center": (300, 300), "radius": 35, "color": (220, 220, 220)},
]

# Draw each coin as a filled circle
for coin in coins:
    center = coin["center"]
    radius = coin["radius"]
    color = coin["color"]
    
    # Draw the coin
    cv2.circle(img, center, radius, color, -1)
    cv2.circle(img, center, radius, (0, 0, 0), 2)

# Save the generated image to a file
cv2.imwrite("synthetic_coins.jpg", img)
# Out:
# True

# %%
# Load the annotated image
annotated_img = cv2.imread("synthetic_coins.jpg")

plt.figure(figsize=(8, 8))
plt.imshow(annotated_img_rgb)
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       1 # Load the annotated image
#       2 annotated_img = cv2.imread("synthetic_coins.jpg")
# ----> 4 plt.figure(figsize=(8, 8))
#       5 plt.imshow(annotated_img_rgb)
#       6 plt.axis("off")
#
# NameError: name 'plt' is not defined
