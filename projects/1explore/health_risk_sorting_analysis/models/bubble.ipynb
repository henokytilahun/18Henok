# %%
#import
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets

# %%
#numbers from 0 to 10
risk_scores = list(np.random.randint(1, 100, 10))

# %%
risk_scores #check values
# Out:
# [97, 3, 69, 88, 15, 77, 59, 72, 98, 12]

# %%
def bubble_sort(arr):
    arr = arr.copy()
    steps = [arr.copy()]
    n = len(arr)
    for i in range(n):
        for j in range(n - i - 1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
                steps.append(arr.copy())
    return steps
steps = bubble_sort(risk_scores)

# %%
steps #check if sorted
# Out:
# [[97, 3, 69, 88, 15, 77, 59, 72, 98, 12],
#  [3, 97, 69, 88, 15, 77, 59, 72, 98, 12],
#  [3, 69, 97, 88, 15, 77, 59, 72, 98, 12],
#  [3, 69, 88, 97, 15, 77, 59, 72, 98, 12],
#  [3, 69, 88, 15, 97, 77, 59, 72, 98, 12],
#  [3, 69, 88, 15, 77, 97, 59, 72, 98, 12],
#  [3, 69, 88, 15, 77, 59, 97, 72, 98, 12],
#  [3, 69, 88, 15, 77, 59, 72, 97, 98, 12],
#  [3, 69, 88, 15, 77, 59, 72, 97, 12, 98],
#  [3, 69, 15, 88, 77, 59, 72, 97, 12, 98],
#  [3, 69, 15, 77, 88, 59, 72, 97, 12, 98],
#  [3, 69, 15, 77, 59, 88, 72, 97, 12, 98],
#  [3, 69, 15, 77, 59, 72, 88, 97, 12, 98],
#  [3, 69, 15, 77, 59, 72, 88, 12, 97, 98],
#  [3, 15, 69, 77, 59, 72, 88, 12, 97, 98],
#  [3, 15, 69, 59, 77, 72, 88, 12, 97, 98],
#  [3, 15, 69, 59, 72, 77, 88, 12, 97, 98],
#  [3, 15, 69, 59, 72, 77, 12, 88, 97, 98],
#  [3, 15, 59, 69, 72, 77, 12, 88, 97, 98],
#  [3, 15, 59, 69, 72, 12, 77, 88, 97, 98],
#  [3, 15, 59, 69, 12, 72, 77, 88, 97, 98],
#  [3, 15, 59, 12, 69, 72, 77, 88, 97, 98],
#  [3, 15, 12, 59, 69, 72, 77, 88, 97, 98],
#  [3, 12, 15, 59, 69, 72, 77, 88, 97, 98]]

# %%
def plot_sort_step(step):
    plt.figure(figsize=(8,4))
    plt.bar(range(len(steps[step])), steps[step], color='orange')
    plt.title(f"Bubble Sort Step {step+1} of {len(steps)}")
    plt.xlabel("Patient Index")
    plt.ylabel("Risk Score")
    plt.ylim(0, max(risk_scores)+10)
    plt.grid(True)
    plt.show()

widgets.interact(plot_sort_step, step=widgets.IntSlider(min=0, max=len(steps)-1, step=1, value=0))
# Out:
# interactive(children=(IntSlider(value=0, description='step', max=23), Output()), _dom_classes=('widget-interac…
# <function __main__.plot_sort_step(step)>
