# %%
#import
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets

# %%
#Create a array of numbers from 0 to 10
risk_scores = list(np.random.randint(1, 100, 15))

# %%
risk_scores #check values
# Out:
# [40, 3, 74, 7, 81, 67, 4, 53, 96, 43, 18, 41, 42, 84, 74]

# %%
#Quick Sort
def quick_sort_steps(arr):
    steps = [arr.copy()]  # record the initial state

    def quick_sort(arr, low, high):
        if low < high:
            pivot_index = partition(arr, low, high)
            quick_sort(arr, low, pivot_index - 1)
            quick_sort(arr, pivot_index + 1, high)

    def partition(arr, low, high):
        pivot = arr[high]
        i = low - 1
        for j in range(low, high):
            if arr[j] <= pivot:
                i += 1
                # Swap arr[i] and arr[j] if needed
                arr[i], arr[j] = arr[j], arr[i]
                steps.append(arr.copy())
        # Swap the pivot into the correct position
        arr[i + 1], arr[high] = arr[high], arr[i + 1]
        steps.append(arr.copy())
        return i + 1

    quick_sort(arr, 0, len(arr) - 1)
    return steps

steps = quick_sort_steps(risk_scores.copy())

# %%
steps #check if sorted
# Out:
# [[62, 58, 79, 98, 9, 13, 54, 25, 88, 27, 65, 86, 80, 79, 87],
#  [62, 58, 79, 98, 9, 13, 54, 25, 88, 27, 65, 86, 80, 79, 87],
#  [62, 58, 79, 98, 9, 13, 54, 25, 88, 27, 65, 86, 80, 79, 87],
#  [62, 58, 79, 98, 9, 13, 54, 25, 88, 27, 65, 86, 80, 79, 87],
#  [62, 58, 79, 9, 98, 13, 54, 25, 88, 27, 65, 86, 80, 79, 87],
#  [62, 58, 79, 9, 13, 98, 54, 25, 88, 27, 65, 86, 80, 79, 87],
#  [62, 58, 79, 9, 13, 54, 98, 25, 88, 27, 65, 86, 80, 79, 87],
#  [62, 58, 79, 9, 13, 54, 25, 98, 88, 27, 65, 86, 80, 79, 87],
#  [62, 58, 79, 9, 13, 54, 25, 27, 88, 98, 65, 86, 80, 79, 87],
#  [62, 58, 79, 9, 13, 54, 25, 27, 65, 98, 88, 86, 80, 79, 87],
#  [62, 58, 79, 9, 13, 54, 25, 27, 65, 86, 88, 98, 80, 79, 87],
#  [62, 58, 79, 9, 13, 54, 25, 27, 65, 86, 80, 98, 88, 79, 87],
#  [62, 58, 79, 9, 13, 54, 25, 27, 65, 86, 80, 79, 88, 98, 87],
#  [62, 58, 79, 9, 13, 54, 25, 27, 65, 86, 80, 79, 87, 98, 88],
#  [62, 58, 79, 9, 13, 54, 25, 27, 65, 86, 80, 79, 87, 98, 88],
#  [62, 58, 79, 9, 13, 54, 25, 27, 65, 86, 80, 79, 87, 98, 88],
#  [62, 58, 79, 9, 13, 54, 25, 27, 65, 86, 80, 79, 87, 98, 88],
#  [62, 58, 79, 9, 13, 54, 25, 27, 65, 86, 80, 79, 87, 98, 88],
#  [62, 58, 79, 9, 13, 54, 25, 27, 65, 86, 80, 79, 87, 98, 88],
#  [62, 58, 79, 9, 13, 54, 25, 27, 65, 86, 80, 79, 87, 98, 88],
#  [62, 58, 79, 9, 13, 54, 25, 27, 65, 86, 80, 79, 87, 98, 88],
#  [62, 58, 79, 9, 13, 54, 25, 27, 65, 86, 80, 79, 87, 98, 88],
#  [62, 58, 79, 9, 13, 54, 25, 27, 65, 86, 80, 79, 87, 98, 88],
#  [62, 58, 79, 9, 13, 54, 25, 27, 65, 79, 80, 86, 87, 98, 88],
#  [62, 58, 79, 9, 13, 54, 25, 27, 65, 79, 80, 86, 87, 98, 88],
#  [62, 58, 79, 9, 13, 54, 25, 27, 65, 79, 80, 86, 87, 98, 88],
#  [62, 58, 9, 79, 13, 54, 25, 27, 65, 79, 80, 86, 87, 98, 88],
#  [62, 58, 9, 13, 79, 54, 25, 27, 65, 79, 80, 86, 87, 98, 88],
#  [62, 58, 9, 13, 54, 79, 25, 27, 65, 79, 80, 86, 87, 98, 88],
#  [62, 58, 9, 13, 54, 25, 79, 27, 65, 79, 80, 86, 87, 98, 88],
#  [62, 58, 9, 13, 54, 25, 27, 79, 65, 79, 80, 86, 87, 98, 88],
#  [62, 58, 9, 13, 54, 25, 27, 65, 79, 79, 80, 86, 87, 98, 88],
#  [9, 58, 62, 13, 54, 25, 27, 65, 79, 79, 80, 86, 87, 98, 88],
#  [9, 13, 62, 58, 54, 25, 27, 65, 79, 79, 80, 86, 87, 98, 88],
#  [9, 13, 25, 58, 54, 62, 27, 65, 79, 79, 80, 86, 87, 98, 88],
#  [9, 13, 25, 27, 54, 62, 58, 65, 79, 79, 80, 86, 87, 98, 88],
#  [9, 13, 25, 27, 54, 62, 58, 65, 79, 79, 80, 86, 87, 98, 88],
#  [9, 13, 25, 27, 54, 62, 58, 65, 79, 79, 80, 86, 87, 98, 88],
#  [9, 13, 25, 27, 54, 62, 58, 65, 79, 79, 80, 86, 87, 98, 88],
#  [9, 13, 25, 27, 54, 62, 58, 65, 79, 79, 80, 86, 87, 98, 88],
#  [9, 13, 25, 27, 54, 62, 58, 65, 79, 79, 80, 86, 87, 98, 88],
#  [9, 13, 25, 27, 54, 62, 58, 65, 79, 79, 80, 86, 87, 98, 88],
#  [9, 13, 25, 27, 54, 58, 62, 65, 79, 79, 80, 86, 87, 98, 88],
#  [9, 13, 25, 27, 54, 58, 62, 65, 79, 79, 80, 86, 87, 98, 88],
#  [9, 13, 25, 27, 54, 58, 62, 65, 79, 79, 80, 86, 87, 98, 88],
#  [9, 13, 25, 27, 54, 58, 62, 65, 79, 79, 80, 86, 87, 88, 98]]

# %%
def plot_quick_sort_step(step):
    plt.figure(figsize=(8,4))
    plt.bar(range(len(steps[step])), steps[step], color='skyblue')
    plt.title(f"Quick Sort - Step {step+1} of {len(steps)}")
    plt.xlabel("Patient Index")
    plt.ylabel("Risk Score")
    plt.ylim(0, max(risk_scores) + 10)
    plt.grid(True)
    plt.show()

widgets.interact(plot_quick_sort_step, step=widgets.IntSlider(min=0, max=len(steps)-1, step=1, value=0))
# Out:
# interactive(children=(IntSlider(value=0, description='step', max=37), Output()), _dom_classes=('widget-interac…
# <function __main__.plot_quick_sort_step(step)>
