# %% [markdown]
# # Brainstorm
#
# The first item of business is to **identify a problem to solve or a question to answer** using the tools from class e.g. `matplotlib`, `ipywidgets`, `numpy`, `scipy`, `pandas`, and `scikit-learn`. This section is designed to help you come up with a project that is interesting to you and aligns with the current unit.
#
# ## Top-down
#
# You may already have a topic or a dataset in mind that you would like to use for the project. In the top-down approach to project development, you start with an ideal output, then assemble the tools to make it happen.
#
# Here are some sources you can use to identify datasets you might use for a project:
#
# * Make your own! Believe it or not, there is a lot of data you already collect that you might use for a project. Your internet search history, posts to social media, fitbit data, photos, etc. Many of these tools have ways of exporting the data into a useable format for data analysis.
# * North Carolina State maintains a [list of cool open source databases](https://www.lib.ncsu.edu/formats/teaching-and-learning-datasets). You could find something from the public sector like NASA, or the private sector like bike companies. All can make cool projects. Do some digging here to find something cool!
# * If you want to try something local, check out the datasets maintained by the state of Nevada. There isn't a central portal, but you can try looking up data maintained by the Department of Health and Human Services, the Division of Minerals, the Office of Economic Development, and the Department of Transportation. These may be particularly interesting for geospatial datasets.
#
# After you have identified a dataset, think of what kind of questions you could answer with the data.
#
# ## Bottom-up
#
# On the other end of the spectrum, maybe you know the kind of data analysis tools you would like to use, but you don't have a problem or dataset to use them on.
#
# You can start brainstorming project ideas by examining the API, tutorials, or gallery sections of the packages from class:
# * [matplotlib](https://matplotlib.org/stable/api/index)
# * [ipywidgets](https://ipywidgets.readthedocs.io/en/latest/)
# * [numpy](https://numpy.org/doc/2.2/reference/index.html)
# * [scipy](https://docs.scipy.org/doc//scipy/reference/index.html)
# * [pandas](https://pandas.pydata.org/pandas-docs/stable/reference/index.html)
# * [scikit-learn](https://scikit-learn.org/stable/api/index.html)
#
# Maybe you want to use a more sophisticated version of an algorithm in class, maybe you want to teach yourself a new function or tool. These can be a great way to ground your project.
#
# However you choose to start your project, whether with a problem, a dataset, or a tool, they can all be used to demonstrate your growth during the unit.
#
# **Please complete below:**
#
# Write provide a reflection (300+ words) about how you chose your project and how it developed.

# %% [markdown]
# The project I chose was exploring the student depression dataset. Originally, I was going to do scam detection but it quickly became something out of my paygrade. Then I did a student performance dataset. There are quite a few on Kaggle but most of them either didn't have a lot of features (columns) or lacked a decent amount of observations (rows). I went quite far in one of the datasets before I took a small break to watch TikTok. There, I saw a lot of videos about the ICE Bucket Challenge. Back in my day, it was to bring awareness to ALS but now it is for mental health. To do my part in increasing awareness, I decided to see if there were any datasets regarding the mental health. I took a long time reviewing different datasets. I met a lot that didn't have the most interesting features or were too small. Finally, I found one that seemed to be a part of a larger dataset with different professions. Unfortunatley, I could not for the life of me find that dataset. I spent like an hour searching. That might not seem like a long time but I was genuinly getting upset. The more upset I was getting, the longer time seemed to be.
#
# When I got the dataset, I messed around with it on different files. I was trying to understand the most important features. That was before I realized that randomforest can find the most important features. So I took some time, hand-translating objects as strings and then mapping to them a numerical value. It was manageable when it was binary or like 4 options but things like Degree and City had like a million different things it could be. I consulted chatGPT and saw something familiar (a label encoder). After feeling stupid for a good minute, I was able to implement the encoder. Then I plotted the most important features. After that, I used the top 5-6 features to train the random forest classifier and got around an 80%. That was well above the baseline of 59% from the dummy classifier.
#
# Then I had to implement the neural network portion. This took the bulk of my time. Even after figuring out how to create the barest nn from patch working different tutorials from the geeks for geeks, the highest percentage I could get was 40%. I knew something had to be wrong. I was on stack overflow, I was on different sites. I was searching why my model went from 80% accuracy during the first epoch and then dipped down to 40% right after and stayed there. My graph of the accuracy score had entire blocks where it dipped down in an unnatural way. After a lot of heartbreak and loss of sanity, the issue ended up being that I had missing values in the financial stress column. A total of 3 missing values to be exact. After dealing with that, my accuracy score shot op to 83-85 range. I noticed that the more features I gave it, the better results I got. My main concern started to be wondering if I overfit the model. Because of that, I went back to the original features given by the feature importance.

# %% [markdown]
# # Develop
#
# Your final project will need to include the following components:
#
# * **Background and Motivation**. Before you show the audience any of your analysis, you need to appropriate set the stage. What is your problem important or interesting? What specific problem are you trying to solve? And is there any essential background that your audience will need to know? You will need to include sources as a part of this.
# * **Analysis and Discussion**. This is where you solve your selected problem using the programming tools from class. Please do **not** walk us through line by line of your code. There isn't enough time, and it is not an effective way to present a coding project. You will use Jupyter slides to help organize your project into bite-size pieces. You can and should skip code, highlighting only the important points that illustrate interesting functions or algorithms, dashboards, and plots. You should also try to break your large problem down into smaller stories, say three sub-problems.
#
# Create an outline of your project below. You can use the template provided to get you started:

# %% [markdown]
# * **Introduction**: how do you solve for x?
#     - **The hook**: Demonstration of problem using physical objects or a widget
#     - **The problem**: State the problem and how we're going to solve it
#     - **Essential background**: key terms, concepts, functions the audience needs to know. Keep it brief!
#     - **Sources used**: Cite these as you introduce new information.
#
# * **Subproblem 1**:
#     - Tools I will use to solve it, subsets of the data I will examine
#     - Key takeaways of analysis
#
# * **Subproblem 2**:
#     - Tools I will use to solve it, subsets of the data I will examine
#     - Key takeaways of analysis

# %% [markdown]
# # Refine
#
# You are required to get feedback from a peer on your project. You may complete this during the in-class Sandbox sessions or outside of class on your own time. Please summarize the feedback from your peer here, as well as how you addressed the feedback.
#
# ## Background and Motivation
#
# 1. **Motivation**: Is the problem well motivated? Do I feel this is worth my time listening to, based on the first 30 seconds?
# 2. **Background**: Is just enough information given to the audience to understand the presentation? Too much or too little? Is this information well organized and presented?
# 3. **Problem-oriented**: Does the project seek to address a specific question or solve a specific problem?
#
# ## Implementation
#
# 1. **Correct**: Is the code technically correct? Are there errors, bugs, etc? This will require more than a superficial glance at the code. Walk through the code line by line and note any problems.
# 2. **Annotated**: Does the code make good use of comments to help guide the interested reader?
# 3. **On topic**: Does the project use tools from the current unit?
# 4. **Complexity**: Is the project of adequte complexity? Does it go a step beyond what we did in class?
#
# ## Presentation
#
# 1. **Correct length**: Is the project too small or too big?
# 2. **Takeaways**: Does the presentation include discussion of the results, rather than just letting the results stand on their own?
# 3. **Aesthetics**: Does the project use good principles of design? Not too text-heavy, includes visuals, etc.

# %% [markdown]
# # Reflect
#
# Take some time to reflect on your presentation after it has been completed, as well as the presentations of your peers. Please address the following prompts in 300+ words each:
#
# 1. How did your presentation go? What were it's strengths and weaknesses? What would you like to do better next time?

# %% [markdown]
# I think my presentation went well. I definietly could have made sure and slacked the professeur to make sure all my packages were installed. Especially something like tensorflow which is quite time consuming. I could also have spent more time explaining the parts of the neural network. My flow got messed up after realizing it didn't work so I just rushed to the conclusion. I think practicing more would have made a better presentation.

# %% [markdown]
# 2. What questions did the audience ask and were you able to answer them? Based on audience questions, is there anything you would add or change about your presentation?

# %% [markdown]
# I was able to answer the question Professor Curtis asked. It was clarifying what features I used to test the model. Probably because I was nervious, I didn't go into detail explaning which features I used. If I could do it again, I would make sure to clarify that point and better explain myself.

# %% [markdown]
# 3. What were some highlights for you from presentations of your peers?

# %% [markdown]
# Honestly, I really liked the variety of topics and datasets chosen. We went from data analysis to machine learning topics. They really showcased a lot of what we learned from class. If I had to pick just a few people, it would be John's, Jules', and Julio's group. They always come prepared and with intersting topics. John and Jules are so good at presenting it is crazy. They seem so professonial. Especially John. He not only understands the topic but is a very good communicator.

# %% [markdown]
# # AI Acknowledgement Statement
#
# Please indicate if and how you used ChatGPT or other LLMs on this assignment. Use the option that best fits your use case:
#
# * [ ] I did not use ChatGPT/LLMs.
# * [X] I consulted ChatGPT/LLMs (to brainstorm, to debug, to get information, to give feedback), but I did not copy and paste or use text directly from ChatGPT/LLMs.
# * [ ] I copied and pasted portions of code directly from ChatGPT/LLMs.
# * [ ] I consulted other outside sources other than ChatGPT/LLMs.
#
# Please provide any and all links to ChatGPT/LLM conversations or other sources used in this assignment and describe how they were used:
#
# | Problem          | Link                                     | Description                                   |
# |------------------|------------------------------------------|-----------------------------------------------|
# | 1                | [Link Example](https://www.google.com/) | I used ChatGPT to help debug error messages. |
# | &nbsp;           | &nbsp;                                  | &nbsp;                                       |
# | &nbsp;           | &nbsp;                                  | &nbsp;                                       |
# | &nbsp;           | &nbsp;                                  | &nbsp;                                       |

# %% [markdown]
# Dataset Source: https://www.kaggle.com/datasets/hopesb/student-depression-dataset
#
# https://www.tensorflow.org/api_docs/python/tf/keras = tensorflow
# https://keras.io/getting_started/ = keras
#
# https://www.geeksforgeeks.org/introduction-to-tensorflow/ = quick overview of tensorflow. This was before you demonstrated how it works in class.
#
# https://www.geeksforgeeks.org/how-to-reshape-a-tensor-in-tensorflow/ = understanding what the reshape function does.
#
# https://www.geeksforgeeks.org/graphs-and-functions-in-tensorflow/ = understanding how to plot graphs and functions in tensorflow. Plotting is a huge part of what we learned after all.
#
# https://www.geeksforgeeks.org/implementing-neural-networks-using-tensorflow/ = understanding how to implement neural networks using tensorflow. This would be the main part of the project.
#
# https://www.geeksforgeeks.org/multi-layer-perceptron-learning-in-tensorflow/ = understanding how to implement a multi-layer perceptron using tensorflow.
#
# https://stackoverflow.com/questions/49332994/python-low-accuracy-with-low-loss-with-tensorflow = understanding why the accuracy is low with low loss in tensorflow. I was genuinly going through it
#
# https://www.geeksforgeeks.org/neural-network-layers-in-tensorflow/ = understanding the different layers in a neural network using tensorflow.
#
#
# https://www.geeksforgeeks.org/loss-function-in-tensorflow/ = understanding the loss function in tensorflow. How this would impact my model.
#
#
# https://www.geeksforgeeks.org/optimizers-in-tensorflow/ = Let me optimize my code. Especially understanding what the Adam optimizer does.
#
#
# https://www.geeksforgeeks.org/tf-keras-callbacks-callback-tensorflow-callbacks/ = understanding the callbacks in tensorflow. This would be important for my model to understand when to stop training.
#
# https://www.geeksforgeeks.org/how-to-visualize-training-progress-in-tensorflow/ = Also helped explain how to vizualize and plot the training progress of my model.
#
#
# https://datascience.stackexchange.com/questions/93294/keras-very-low-accuracy-saturate-after-few-epochs-while-training = helped understand why my accuracy was still so low.
#
# https://chatgpt.com/share/681241da-c4b0-800f-915e-232e34c0d3a6 = Helped me figure out the encoder.
