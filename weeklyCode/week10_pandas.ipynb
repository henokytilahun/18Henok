# %%
import pandas as pd #pd is the common name for pandas
import numpy as np #np is the common name for numpy

# %%
data = {'name': ['Bulbasaur', 'Charmander', 'Squirtle'], 'type': ['grass', 'fire', 'water']}
df = pd.DataFrame(data) #df is the common name for a DataFrame

# %%
#getting the first row
print(df.iloc[0]) #iloc treats it as numpy array and gets the first row
# Out:
# name    Bulbasaur
# type        grass
# Name: 0, dtype: object

# %%
df['name']
# Out:
# 0     Bulbasaur
# 1    Charmander
# 2      Squirtle
# Name: name, dtype: object

# %%
type(df) # type = dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['name']) # type = series
# Out:
# pandas.core.series.Series

# %%
#read data from excel spreadsheet
data = pd.read_excel('/Users/henok/Dropbox/18Henok/weeklyCode/pokemon.xlsx') # gets the second sheet

#data = pd.read_excel('/Users/henok/Dropbox/18Henok/weeklyCode/pokemon.xlsx', sheet_name=1) # gets the second sheet
#sheet_name, skiprows, usecols
#data = pd.read_excel('/Users/henok/Dropbox/18Henok/weeklyCode/pokemon.xlsx', skiprows=1) # skips the first row
#data = pd.read_excel('/Users/henok/Dropbox/18Henok/weeklyCode/pokemon.xlsx', usecols='A:C') # gets the first three columns
#data = pd.read_excel('/Users/henok/Dropbox/18Henok/weeklyCode/pokemon.xlsx', index_col='Name') # sets the index column




df = pd.DataFrame(data)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#       #       Name    Type  Total  HP  Attack  Defense  Special Attack  \
# 0   001  Bulbasaur   GRASS    318  45      49       49              65
# 1   001  Bulbasaur  POISON    318  45      49       49              65
# 2   002    Ivysaur   GRASS    405  60      62       63              80
# 3   002    Ivysaur  POISON    405  60      62       63              80
# 4   003   Venusaur   GRASS    525  80      82       83             100
#
#    Special Defense  Speed
# 0               65     45
# 1               65     45
# 2               80     60
# 3               80     60
# 4              100     80

# %% [markdown]
# Potential Data Analysis
#
# - Which pokemon has the strongest [insert attribute]?
#
# - Which pokemon has the most rounded dataset
#
# - Type with the highest total HP
#
# - Which pokemon have the most variation (4 entries)
#
# - What if we could combine the types (bulbasaur Grass/Poison)
#
# - Which type has the most pokemon
#
# - How many multiple type pokemon

# %%
# How to sort the data
df.sort_values('Attack', ascending=True) #accesing
# Out:
#           #                  Name      Type  Total   HP  Attack  Defense  \
# 699     440               Happiny    NORMAL    220  100       5        5
# 175     113               Chansey    NORMAL    450  250       5        5
# 336     213               Shuckle      ROCK    505   20      10      230
# 199     129              Magikarp     WATER    200   20      10       55
# 335     213               Shuckle       BUG    505   20      10      230
# ..      ...                   ...       ...    ...  ...     ...      ...
# 617   386.1  Deoxys- Attack Forme   PSYCHIC    600   50     180       20
# 339   214.1        Mega Heracross       BUG    600   80     185      115
# 340   214.1        Mega Heracross  FIGHTING    600   80     185      115
# 236   150.1         Mega Mewtwo X   PSYCHIC    780  106     190      100
# 237   150.1         Mega Mewtwo X  FIGHTING    780  106     190      100
#
#      Special Attack  Special Defense  Speed
# 699              15               65     30
# ...

# %%
#filtering out MEGA types
df['Name'].str.contains('Mega ')
df[~df['Name'].str.contains('Mega ')] # ~ is the negation operator
# Out:
#          #       Name    Type  Total   HP  Attack  Defense  Special Attack  \
# 0      001  Bulbasaur   GRASS    318   45      49       49              65
# 1      001  Bulbasaur  POISON    318   45      49       49              65
# 2      002    Ivysaur   GRASS    405   60      62       63              80
# 3      002    Ivysaur  POISON    405   60      62       63              80
# 4      003   Venusaur   GRASS    525   80      82       83             100
# ...    ...        ...     ...    ...  ...     ...      ...             ...
# 1163   716    Xerneas   FAIRY    680  126     131       95             131
# 1164   717    Yveltal    DARK    680  126     131       95             131
# 1165   717    Yveltal  FLYING    680  126     131       95             131
# 1166   718    Zygarde  DRAGON    600  108     100      121              81
# 1167   718    Zygarde  GROUND    600  108     100      121              81
#
#       Special Defense  Speed
# 0                  65     45
# ...

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
def convert_to_int(val):
    try:
        return int(val)
    except ValueError:
        return np.nan

# %%
data = pd.read_excel('pokemon.xlsx', converters={'#' : convert_to_int}) # gets the second sheet

# %%
df[df['Name']].isin(['Mega',])

 df = df['Type'] == 'FIRE' # returns a boolean series
firstGen = df['#'] < 152 
df[locFire and firstGen] # this will not work because and is not supported for series
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 2
#       1 locFire = df['Type'] == 'FIRE' # returns a boolean series
# ----> 2 firstGen = df['#'] < 152
#       3 df[locFire and firstGen]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/ops/common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/arraylike.py:48, in OpsMixin.__lt__(self, other)
#      46 @unpack_zerodim_and_defer("__lt__")
#      47 def __lt__(self, other):
# ---> 48     return self._cmp_method(other, operator.lt)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:6096, in Series._cmp_method(self, other, op)
# ...

# %%
#select data
datanum = df.select_dtypes(include=['number'])

#scatterplot of all columns
datanum.plot(kind='scatter', x='Attack', y='Defense')
# Out:
# <Axes: xlabel='Attack', ylabel='Defense'>
